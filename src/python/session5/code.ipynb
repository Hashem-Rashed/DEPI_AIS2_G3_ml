# %%
class Student:
   
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def get_info(self):
        return f"My name is {self.name}, age is {self.age}"

# %%
s1 = student("hashem",20)
s1.get_info()
# Out:
# 'my name is hashem, age is 20'

# %%
class Student:

    def __init__(self, name="test", age = 20):
        self.name = name
        self.age = age

    def get_info(self):
        return f"my name is {self.name}, age is {self.age}"

# %%
s1 = Student()
s1.get_info()
# Out:
# 'my name is test, age is 20'

# %%
from abc import ABC, abstractmethod

class Animal(ABC):


    def move(self):
        pass

class Bird(Animal):


    def move(self):
        print("move from Bird")

class Cat(Animal):
    def move(self):
        print("move fron cat")

# %%
a = Cat()
a.move()
# Out:
# move fron cat

# %%
class car :
    __name = "DEPI"

    def __get_info(self):
        print("car")
        
c1 =car()
c1.__name
# Out:
# 'DEPI'

# %%
class Calculator1:
    def summation(self,n1,n2):
        return n1+n2

    def subtraction(self,n1,n2):
        return n1-n2

    def multiplication(self,n1,n2):
        return n1*n2

    def division(self,n1,n2):
        return n1/n2

class Calculator2(Calculator1):

    def power(self,n1,n2):
        return n1 ** n2

c1 = Calculator2()
print(c1.summation(2,5))
# Out:
# 7

# %%
class A():
    def do_this(self):
        print("I am in A")

class B(A):
    pass

class C():
    def do_this(self):
        print("I am in C")

class D(B,C): #---------
    pass

x = D()
x.do_this()
# Out:
# I am in A

# %%
class A():
    def do_this(self):
        print("i am in A")
class B(A):
    pass
class C():
    def do_this(self):
        print("i am in C")

class D(C,B): #-------------
    pass

a = D()
a.do_this()
# Out:
# i am in C

# %%
import random

admin_user = "test"
admin_password = "1111"


def login():
    print("Store App")
    while True:
        x = input ("Enter your username :  ")
        if x== admin_user:
            y =input("Enter you password")
            if y==admin_password :
                s =random.randrange(10000,100000)
                print(f"Verification code is : {s}")
                while True:
                    try:
                        l =int(input("Enter the verificatuon code"))
                        if l == s:
                            print("access granter\n") 
                            return True
                        else:
                            print("Invalid verification code .please try again")
                    except ValueError:
                        print ("Please enter numeers only")
            else:
                print("incorrect password")
        else:
            print("incorrect username")

# %%
login()
# Out:
# Store App
# Verification code is : 17252
# Invalid verification code .please try again
# Invalid verification code .please try again
# access granter
# True

# %%
! pip install Prettytable
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Prettytable in c:\users\hashem\appdata\roaming\python\python312\site-packages (3.17.0)
# Requirement already satisfied: wcwidth in c:\users\hashem\appdata\roaming\python\python312\site-packages (from Prettytable) (0.2.14)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from prettytable import PrettyTable

products = [{"name": "water", "price": 80.0, "quantity": 1500},
            {"name": "Soda", "price": 130.0, "quantity": 1500},
            {"name": "Chips", "price": 75.0, "quantity": 1500},
            {"name": "Bread", "price": 45.0, "quantity": 1500},
            {"name": "Eggs", "price": 200.0, "quantity": 1500}]

table = PrettyTable()
table.field_names = ["Product Name", "Price ($)", "Quantity"]

for p in products:
    table.add_row([p["name"],f"{p['price']:.2f}",p["quantity"]])
print(table)
total_bill =0

while True:
    product_name = input("\nEnter product name (or 'exit') to finish: ").strip().lower()
    if product_name == 'exit':
        break
    product = next((p for p in products if p['name'].lower() == product_name), None)

    if product is None:
        print("product not found. please try again")
        continue
    try:
        quantity_required = float(input(f"How many {product['name']} do you want?"))
        if quantity_required <= 0:
            print("Quantity must be greater than Zero")
            continue
        if quantity_required > product['quantity']:
            print(f"insufficient quantitt!")
            continue
        discount_percentage =0.05
        price_before_disc = quantity_required * product['price']
        discount_amount = price_before_disc * discount_percentage
        final_price = price_before_disc - discount_amount

        product['quantity' ] -= quantity_required
        total_bill += final_price
        print(f"Success! price for {product['name']}: ${final_price :.2f}(saved: ${discount_amount :.2f})")
        another =input("sonething else? (y/n)").lower()
        if another != 'y':
            break
    except ValueError:
        print("Invalid input! pls enter a number for qty")
print(f"\n Total Amount to pay: ${total_bill:.2f}")
print("thank you !")
# Out:
# +--------------+-----------+----------+
# | Product Name | Price ($) | Quantity |
# +--------------+-----------+----------+
# |    water     |   80.00   |   1500   |
# |     Soda     |   130.00  |   1500   |
# |    Chips     |   75.00   |   1500   |
# |    Bread     |   45.00   |   1500   |
# |     Eggs     |   200.00  |   1500   |
# +--------------+-----------+----------+
# Success! price for water: $3800.00(saved: $200.00)
#
#  Total Amount to pay: $3800.00
# thank you !

# %%
from prettytable import PrettyTable
 
products = [{"name":"water","price":80.0,"quantity":1500},
            {"name":"Soda","price":130.0,"quantity":1500},
            {"name":"Chips","price":75.0,"quantity":1500},
            {"name":"Bread","price":45.0,"quantity":1500},
            {"name":"Eggs","price":200.0,"quantity":1500}
             ]
table = PrettyTable()
table.field_names = ["Product Name","Price($)", "Quantity"]

for p in products:
    table.add_row([p["name"],f"{p['price']:.2f}", p["quantity"]])
print(table)
total_bill = 0
 
while True:
    product_name = input("\nEnter product name (or 'exit') to finish: ").strip().lower()
    if product_name == 'exit':
        break
    product = next((p for  p in products if p['name'].lower() == product_name), None)
   
    if product is None:
        print("product not found. please try again")
        continue
    try:
        quantity_required = float(input(f"How many {product['name']} do you want?"))
        if quantity_required <=0:
            print("Quantity must be greater than Zero")
            continue
        if quantity_required > product['quantity']:
            print(f"Insufficient quantity!")
            continue
        discount_percentage = 0.05
        price_before_disc = quantity_required * product['price']
        discount_amount = price_before_disc * discount_percentage
        final_price = price_before_disc - discount_amount
       
        product['quantity'] -= quantity_required
        total_bill += final_price
        print(f"Success! price for {product['name']}: ${final_price:.2f}(saved: ${discount_amount:.2f})")
        another = input("something else? (y/n)").lower()
        if another != 'y':
            break
    except ValueError:
        print("Invalid input! pls enter a number for qty")
print(f"\n Total Amount to pay: ${total_bill:.2f}")
print("thank you !")
# Out:
# +--------------+----------+----------+
# | Product Name | Price($) | Quantity |
# +--------------+----------+----------+
# |    water     |  80.00   |   1500   |
# |     Soda     |  130.00  |   1500   |
# |    Chips     |  75.00   |   1500   |
# |    Bread     |  45.00   |   1500   |
# |     Eggs     |  200.00  |   1500   |
# +--------------+----------+----------+
# Success! price for water: $380.00(saved: $20.00)
# Success! price for Soda: $12350.00(saved: $650.00)
#
#  Total Amount to pay: $12730.00
# thank you !
