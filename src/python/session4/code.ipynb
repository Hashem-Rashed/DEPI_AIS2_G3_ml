# %%
def fact_fun(num):
    if num ==0:
        return 1
    # if num==1:
    #     return 1

    return num * fact_fun(num -1)

# %%
fact_fun(5)
# Out:
# 120

# %%
def is_prime(num):
    for i in range(2,num):
        if num%i ==0 :
            return False
        

    return True

# %%
is_prime(10)
# Out:
# False

# %%
def dividors (num1 :int,num2 :int):
    mn=min(num1,num2)
    common_div=[]
    for i in range(1,mn+1):
        if num1%i ==0 and num2 %i ==0:
            common_div.append(i)
    return common_div

# %%
dividors(20,10)
# Out:
# [1, 2, 5, 10]

# %%
import random

def random_pass(length):

    char = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
    password =""
    for _ in range(length):
        password += random.choice(char)
    return password

# %%
class PasswordGenerator:
    def __init__(self):
        self.length = 8
        self.characters = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
    def generate_password(self,length):
        password = ""
        num_of_chars = len(self.characters)
       
        for _ in range(self.length):
            rand_index = random.randrange(0, num_of_chars)
            password += self.characters[rand_index]
       
        return password
 
# Usage example
if __name__ == "__main__":
   
    # password_length = 8  # You can change this to your desired length
    generator = PasswordGenerator()
    random_password = generator.generate_password(8)
    print(random_password)
# Out:
# Pu&zM*bj

# %%
print(random_pass(8))
# Out:
# ZC6M&8B5

# %% [markdown]
# words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]

# %%
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
unique_word = set(words)
count = {word: 0 for word in unique_word}
for i in unique_word:
    for j in words:
        if j in words:
            count[i] +=1

count
# Out:
# {'Welcome': 10, 'No': 10, 'Hi': 10, 'Ali': 10}

# %%
def count_words(words_list):

    """
    Count the frequency of each word in a list.

    Parameters:
    words_list (list): List of words to count

    Returns:
    dict: Dictionary with words as keys and counts as values

    """

    word_counts = {}

    for word in words_list:
        if word in word_counts:
            word_counts[word] += 1
        else:
            word_counts[word] = 1

    return word_counts

# %%
words = ["Welcome", "All", "Hi", "All", "No", "Hi", "No", "All", "No", "All"]
result = count_words(words)
result
# Out:
# {'Welcome': 1, 'All': 4, 'Hi': 2, 'No': 3}

# %%
def count_word(words:list):


    unique_word = set(words)
    count = {word: 0 for word in unique_word}
    for i in unique_word:
        for j in words:
            if i ==j:
                count[i] +=1

    return count

# %%
count_word(["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"])
# Out:
# {'Welcome': 1, 'No': 3, 'Hi': 2, 'Ali': 4}

# %%
responses = {
    "hello": ["Hello!", "Hi there!", "Greetings!"],
    "how are you": ["I'm doing well, thank you!", "I'm fine, how about you?"],
    "goodbye": ["Goodbye!", "See you later!", "Farewell!"],
    "default": ["I'm sorry, I didn't understand.", "Could you please rephrase that?"]
}

def get_response(user_input):
    for key in responses:
        if key in user_input:
            return random.choice(responses[key])
    return random.choice(responses["default"])

def chatbot():
    print("chatbot :hi! how can assist you today? ")
    while True :
        user_input =input("user:    ").lower()
        response = get_response(user_input)
        print("Chatbot: ", response)

        if user_input == "goodbye":
            break
if __name__ == " main_":
    chatbot()

# %%
get_response("hello!")
chatbot()
# Out:
# chatbot :hi! how can assist you today?
# Chatbot:  I'm sorry, I didn't understand.
# Chatbot:  Could you please rephrase that?
# Chatbot:  Farewell!

# %%
class StudentInfo:

    
    def __init__(self,name,age,gpa,course):

            
        self.name =name
        self.age=age
        self.gpa =gpa
        self.course =course

    def get_info(self):
        return f"my name is {self.name} ,and my age is {self.age}"

# %%
s1 = StudentInfo("hashem",22,2.7,"ml")
# s1.name="hash"
# s1.name
# s1.get_info()
# print(s1)
print(s1.get_info())
# Out:
# my name is hashem ,and my age is 22
# None

# %%
def reverse_words(s):
    s="The greatest victory is that which requires no battle"
    s.split()
    print(s =s[::-1])
    return s

# %%
def reverse_words(s):
    s="hello world!"
    s=s.split()
    s=s[::-1]
    s=" ".join(s)
    return s

# %%
reverse_words(s)
# Out:
# 'world! hello'
