# %%
text ="###!!@mocleW EPGTQ!!!6789"
print(list(text))
text =text[6:18]
print(text)
text = text[-7:-13:-1]+text[6:]
print(text)
text =text.replace(text[7]," ")
print(text)
# Out:
# ['#', '#', '#', '!', '!', '@', 'm', 'o', 'c', 'l', 'e', 'W', ' ', 'E', 'P', 'G', 'T', 'Q', '!', '!', '!', '6', '7', '8', '9']
# mocleW EPGTQ
# Welcom EPGTQ
# Welcom  PGTQ
