# %%
name ="hashem"
course_neme ="machine learning"
id ="11111"
print(f"my name is {name} and my course neme is {course_neme} and my id is {id}")
# Out:
# my name is hashem and my course neme is machine learning and my id is 11111

# %%
x ="welcome into depi r4"
x.upper()
# Out:
# 'WELCOME INTO DEPI R4'

# %%
x ="welcome into depi r4"
x.lower()
# Out:
# 'welcome into depi r4'

# %%
x ="welcome into depi r4"
x.replace("r4","r5")
# Out:
# 'welcome into depi r5'

# %%
x ="welcome into depi r4 r4 r4"
x.count("r4")
# Out:
# 3

# %%
x ="welcome into depi r4"
x.split
list_1=x.split()
print(list_1)
# Out:
# ['welcome', 'into', 'depi', 'r4']

# %%
sent =' '.join(list_1)
type(sent)
print(sent)
# Out:
# welcome into depi r4

# %%
sent.startswith("welcome")
# Out:
# True

# %%
sent.endswith("welcome")
# Out:
# False

# %%
print("welcome into\nour group")
# Out:
# welcome into
# our group

# %%
input()
# Out:
# '1'

# %%
list_3 =["amit","learning","python","hashem"]
print(list_3)
item=input("enter a item form the list")
list_3.remove(item)
print(list_3)
# Out:
# ['amit', 'learning', 'python', 'hashem']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 4
#       2 print(list_3)
#       3 item=input("enter a item form the list")
# ----> 4 list_3.remove(item)
#       5 print(list_3)
#
# ValueError: list.remove(x): x not in list

# %%
list_4 =["amit","learning","python","hashem","depi"]

list_4.sort()
print(list_4)
# Out:
# ['amit', 'depi', 'hashem', 'learning', 'python']

# %%
tuple_1=(30,20,10,3,40)
# tuple_1[0]=10
print(tuple_1)

list_1= list(tuple_1)
list_1[0]=50
tuple_1=tuple(list_1)
# tuple_1[0]=40
print(tuple_1)
# Out:
# (30, 20, 10, 3, 40)
# (50, 20, 10, 3, 40)

# %%
num_1=int(input("enter the first number: "))
num_2=int(input("enter the first number: "))
print(f"the sum is {num_1+num_2}\n the sub is {num_1-num_2}\n the multi is {num_1*num_2}\n the division is {num_1/num_2}   ")
# Out:
# the sum is 6
#  the sub is 4
#  the multi is 5
#  the division is 5.0

# %%
a=200
b=33
if b>a :
    print("b is greater than a")
elif a==b :
    print("a and b are equal")
else:
    print("a is greater than b")
# Out:
# a is greater than b

# %%
x=5
result = "ever" if x % 2 ==0 else "odd"
print(result)
# Out:
# odd

# %%
a =10
b =5
result  = a + b if a>b else a-b
print(result)
# Out:
# 15

# %%
age =21
print("adult") if age >=18 else (print("teenger") if age >=13 else print("child"))
# Out:
# adult

# %%
degree =int(input("enter your degree"))

if 100 >=degree >=90 :
    print("A")
elif 90>=degree>=80 :
    print("B")
elif 80>=degree>=70 :
    print("C")
elif 70 >=degree>=60 :
    print("D")
elif 60>degree>0:
    print("F")
else  :
    degree =int(input("please enter a valid number"))
# Out:
# F
